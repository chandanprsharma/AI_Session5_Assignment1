# %% [markdown]
# ### Assignment-1 Class5 Solution
# #### By: Chandan Prakash Sharma

# %% [markdown]
# ### 2.1. Problem Statement: PYTHON 1
# #### Q1. Install Jupyter notebook and run the first program and share the screenshot of the output.

# %% [markdown]
# #### Ans: See the below output of my 1st HelloWorld program
#
# ![1.%20HelloWorld%20output.JPG](attachment:1.%20HelloWorld%20output.JPG)

# %% [markdown]
# #### Q2. Write a program which will find all such numbers which are divisible by 7 but are not a multiple of 5, between 2000 and 3200 (both included). The numbers obtained should be printed in a comma-separated sequence on a single line.

# %%
# iterate over range between 2000 and 3200 (both included)
s = ''
for i in range(2000, 3201):
    if (i%7 == 0 and i%5 !=0):
        s += str(i) + ", "
    
print(s[:(len(s)-2)])
# Out:
# 2002, 2009, 2016, 2023, 2037, 2044, 2051, 2058, 2072, 2079, 2086, 2093, 2107, 2114, 2121, 2128, 2142, 2149, 2156, 2163, 2177, 2184, 2191, 2198, 2212, 2219, 2226, 2233, 2247, 2254, 2261, 2268, 2282, 2289, 2296, 2303, 2317, 2324, 2331, 2338, 2352, 2359, 2366, 2373, 2387, 2394, 2401, 2408, 2422, 2429, 2436, 2443, 2457, 2464, 2471, 2478, 2492, 2499, 2506, 2513, 2527, 2534, 2541, 2548, 2562, 2569, 2576, 2583, 2597, 2604, 2611, 2618, 2632, 2639, 2646, 2653, 2667, 2674, 2681, 2688, 2702, 2709, 2716, 2723, 2737, 2744, 2751, 2758, 2772, 2779, 2786, 2793, 2807, 2814, 2821, 2828, 2842, 2849, 2856, 2863, 2877, 2884, 2891, 2898, 2912, 2919, 2926, 2933, 2947, 2954, 2961, 2968, 2982, 2989, 2996, 3003, 3017, 3024, 3031, 3038, 3052, 3059, 3066, 3073, 3087, 3094, 3101, 3108, 3122, 3129, 3136, 3143, 3157, 3164, 3171, 3178, 3192, 3199

# %% [markdown]
# #### Q3. Write a Python program to accept the user's first and last name and then getting them printed in the the reverse order with a space between first name and last name.

# %%
first_name = input('Enter first name: ')
last_name = input('Enter last name: ')
full_name = first_name + ' ' + last_name
print(full_name[::-1])
# Out:
# Enter first name: Chandan
# Enter last name: Sharma
# amrahS nadnahC

# %% [markdown]
# #### Q4. Write a Python program to find the volume of a sphere with diameter 12 cm. (Formula: V=4/3 * π * r^3)

# %%
diameter = 12
pi = 22/7
volume = (4/3) * pi * ((diameter/2)**3)
print(f'Volume of sphere with {diameter}cm diameter is: {volume} cm^3')
# Out:
# Volume of sphere with 12cm diameter is: 905.142857142857 cm^3

# %% [markdown]
# ### 2.2. Problem Statement: PYTHON 2
# #### Q1. Write a program which accepts a sequence of comma-separated numbers from console and generate a list.

# %%
input_data = input('Enter a sequence of comma-separated numbers: ')
li = input_data.split(",")
list_num = []
for i in li:
    list_num.append(int(i))
print(f'Result in list: {list_num}')
# Out:
# Enter a sequence of comma-separated numbers: 1,2,3,4,5
# Result in list: [1, 2, 3, 4, 5]

# %% [markdown]
# #### Q2. Create the below pattern using nested for loop in Python.
# ![2.2.2%20Expeacted_output.JPG](attachment:2.2.2%20Expeacted_output.JPG)

# %%
n = 9
l = f = int(n/2)

for i in range(f):
    for j in range(i+1):
        print('*', end='')
    print()

for i in range(l,-1,-1):
    for j in range(i+1):
        print('*', end='')
    print()
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %% [markdown]
# #### Q3. Write a Python program to reverse a word after accepting the input from the user.
# Sample Output:
#
# Input word: AcadGild
#
# Output: dilGdacA

# %%
input_word = input('Enter a word: ')
print(input_word[::-1])
# Out:
# Enter a word: AcadGild
# dliGdacA

# %% [markdown]
# #### Q4. Write a Python Program to print the given string in the format specified in the sample output.
#
# WE, THE PEOPLE OF INDIA, having solemnly resolved to constitute India into a SOVEREIGN,
# SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC and to secure to all its citizens
#
# ##### Sample Output:
#
# WE, THE PEOPLE OF INDIA,
#
#     having solemnly resolved to constitute India into a SOVEREIGN, !
#
#         SOCIALIST, SECULAR, DEMOCRATIC
#
#             REPUBLIC and to secure to all its citizens

# %%
input_str = 'WE, THE PEOPLE OF INDIA,\n\t having solemnly resolved to constitute India into a SOVEREIGN, !\n\t\t SOCIALIST, SECULAR, DEMOCRATIC\n\t\t\t REPUBLIC and to secure to all its citizens'
print(input_str)
# Out:
# WE, THE PEOPLE OF INDIA,
# 	 having solemnly resolved to constitute India into a SOVEREIGN, !
# 		 SOCIALIST, SECULAR, DEMOCRATIC
# 			 REPUBLIC and to secure to all its citizens

# %% [markdown]
# ### 2.3. Problem Statement: PYTHON 3
# #### Q1.1. Write a Python Program to implement your own myreduce() function which works exactly like Python's built-in function reduce()

# %%
def myreduce(func, arg):
    func(*arg)
    
def findSum(a,b):
    print(a + b)

args = [10, 20]
myreduce(findSum, args)
# Out:
# 30

# %% [markdown]
# #### Q1.2. Write a Python program to implement your own myfilter() function which works exactly like Python's built-in function filter()

# %%
def myfilter(func, arg):
    func(*arg)
    
def isPrime(num):
    flag = True
    for i in range(2,int(num/2)+1):
        if(num%i == 0):
            flag = False
            break
    print(flag)

args = [11]
myfilter(isPrime, args)
# Out:
# True

# %% [markdown]
# #### Q2. Implement List comprehensions to produce the following lists.
# Write List comprehensions to produce the following Lists.
#
# ['A', 'C', 'A', 'D', 'G', 'I', ’L’, ‘ D’]
#
# ['x', 'xx', 'xxx', 'xxxx', 'y', 'yy', 'yyy', 'yyyy', 'z', 'zz', 'zzz', 'zzzz']
#
# ['x', 'y', 'z', 'xx', 'yy', 'zz', 'xxx', 'yyy', 'zzz', 'xxxx', 'yyyy', 'zzzz']
#
# [[2], [3], [4], [3], [4], [5], [4], [5], [6]]
#
# [[2, 3, 4, 5], [3, 4, 5, 6], [4,5, 6, 7], [5, 6, 7, 8]]
#
# [(1, 1), (2, 1), (3, 1), (1, 2), (2, 2), (3, 2), (1, 3), (2, 3), (3, 3)]

# %%
# For Output: ['A', 'C', 'A', 'D', 'G', 'I', ’L’, ‘ D’]
msg1 = 'ACADGILD'
result1 = [letter for letter in msg1]
print(result1)
# Out:
# ['A', 'C', 'A', 'D', 'G', 'I', 'L', 'D']

# %%
# For Output: ['x', 'xx', 'xxx', 'xxxx', 'y', 'yy', 'yyy', 'yyyy', 'z', 'zz', 'zzz', 'zzzz']
msg2 = 'XYZ'
result2 = [row*i for row in msg2 for i in range(1,5)]
print(result2)
# Out:
# ['X', 'XX', 'XXX', 'XXXX', 'Y', 'YY', 'YYY', 'YYYY', 'Z', 'ZZ', 'ZZZ', 'ZZZZ']

# %%
# For Output: ['x', 'y', 'z', 'xx', 'yy', 'zz', 'xxx', 'yyy', 'zzz', 'xxxx', 'yyyy', 'zzzz']
msg3 = 'XYZ'
result3 = [row2*(row1) for row1 in range(1,5) for row2 in msg3]
print(result3)
# Out:
# ['X', 'Y', 'Z', 'XX', 'YY', 'ZZ', 'XXX', 'YYY', 'ZZZ', 'XXXX', 'YYYY', 'ZZZZ']

# %%
# For Output: [[2], [3], [4], [3], [4], [5], [4], [5], [6]]
msg = [2,3,4,5,6,7,8]
result3 = [[row2] for row1 in range(0,3) for row2 in msg[row1:(row1+3)]]
print(result3)
# Out:
# [[2], [3], [4], [3], [4], [5], [4], [5], [6]]

# %%
# For Output: [[2, 3, 4, 5], [3, 4, 5, 6], [4, 5, 6, 7], [5, 6, 7, 8]]
msg = [2,3,4,5,6,7,8]
temp_result = [row2 for row1 in range(0,4) for row2 in msg[row1:(row1+4)]]
result4 = [temp_result[i * 4:(i + 1) * 4] for i in range((len(temp_result) + 4 - 1) // 4 )]

print(result4)
# Out:
# [[2, 3, 4, 5], [3, 4, 5, 6], [4, 5, 6, 7], [5, 6, 7, 8]]

# %%
# For output: [(1, 1), (2, 1), (3, 1), (1, 2), (2, 2), (3, 2), (1, 3), (2, 3), (3, 3)]
# -------------------------------------------------------------------------------------------
msg = [1,2,3]

result5 = [(row2, row1) for row1 in msg for row2 in msg]
print(result5)
# Out:
# [(1, 1), (2, 1), (3, 1), (1, 2), (2, 2), (3, 2), (1, 3), (2, 3), (3, 3)]

# %% [markdown]
# #### Q3. Implement a function longestWord() that takes a list of words and returns the longest one.

# %%
def longestWord(wordList):
    lword = wordList[0];
    for word in wordList[1:]:
        if(len(word)>len(lword)):
            lword = word
    return lword


wordsList = ['Write', 'a', 'Python', 'program', 'to', 'implement', 'your', 'own', 'myfilter', 'function', 'which', 'works', 'exactly', 'like', 'Python']
print('Longest word is: ' + longestWord(wordsList))
# Out:
# Longest word is: implement

# %% [markdown]
# ### 2.4. Problem Statement: PYTHON 4
# #### Q1.1 Write a Python Program(with class concepts) to find the area of the triangle using the below formula.
# ##### area = (s*(s-a)*(s-b)*(s-c)) ** 0.5
# ##### Function to take the length of the sides of triangle from user should be defined in the parent class and function to calculate the area should be defined in subclass.

# %%
class Triangle:

    def __init__(self, a, b, c):
        self.a = a
        self.b = b
        self.c = c

    def findS(self):
        return (self.a + self.b + self.c)/2

class EquilateralTriangle(Triangle):

    def __init__(self, a, b, c):
        Triangle.__init__(self,a, b, c)
        self.s = self.findS()

    def findArea(self):
        return ((self.s*(self.s-self.a)*(self.s-self.b)*(self.s-self.c)) ** 0.5)

    
myTraingle = EquilateralTriangle(3,4,5)
print(myTraingle.findArea())
# Out:
# 6.0

# %% [markdown]
# #### Q1.2 Write a function filter_long_words() that takes a list of words and an integer n and returns the list of words that are longer than n.

# %%
# function that filter words that are greater than n
def filter_long_words(words, n):
    filteredWords = []
    for word in words:
        if(len(word) > n):
            filteredWords.append(word)
    return filteredWords


# list of words
wordsList = ['Write', 'a', 'Python', 'program', 'to', 'implement', 'your', 'own', 'myfilter', 'function', 'which', 'works', 'exactly', 'like', 'Python']
n = 5

filteredWords = filter_long_words(wordsList, n)
print(f'The filtered words (>{n}) are:')
for word in filteredWords:
    print(word)
# Out:
# The filtered words (>5) are:
# Python
# program
# implement
# myfilter
# function
# exactly
# Python

# %% [markdown]
# #### Q2.1 Write a Python program using function concept that maps list of words into a list of integers representing the lengths of the corresponding words.
# ##### Hint: If a list [ ab,cde,erty] is passed on to the python function output should come as [2,3,4].
# ##### Here 2,3 and 4 are the lengths of the words in the list.

# %%
# function that maps list of words into a list of integers representing the lengths of the corresponding words.
def wordLengthMapper(words):
    wordsLength = []
    for word in words:
        wordsLength.append(len(word))
    print(wordsLength)


# list of words
wordsList = ['Write', 'a', 'Python', 'program', 'to', 'implement', 'your', 'own', 'myfilter', 'function', 'which', 'works', 'exactly', 'like', 'Python']
n = 5
wordLengthMapper(wordsList)
# Out:
# [5, 1, 6, 7, 2, 9, 4, 3, 8, 8, 5, 5, 7, 4, 6]

# %% [markdown]
# #### Q2.2 Write a Python function which takes a character (i.e. a string of length 1) and returns True if it is a vowel, False otherwise

# %%
# function that filters vowels
def checkVowels(alphabet):
    vowels = ['a', 'e', 'i', 'o', 'u']

    if(alphabet.lower() in vowels):
        return True
    else:
        return False

# list of alphabets
alphabets = ['a', 'b', 'd', 'E', 'i', 'J', 'o', 'p']
filteredVowels = filter(checkVowels, alphabets)

print(f'The filtered vowels in given list {alphabets} are: ')
for vowel in filteredVowels:
    print(vowel, end=", ")
# Out:
# The filtered vowels in given list ['a', 'b', 'd', 'E', 'i', 'J', 'o', 'p'] are:
# a, E, i, o,

# %% [markdown]
# ### 2.5. Problem Statement: PYTHON 5
# #### Q1. Write a function to compute 5/0 and use try/except to catch the exceptions.

# %%
# function to divide two numbers
def divide(dividend, divisor):
    try:
        quotient = dividend / divisor
        print(f"{dividend} / {divisor} = {quotient}")
        return quotient
    except TypeError as te:
        # handle TypeError exception
        print('Error: ' + str(te))
    except ZeroDivisionError as zde:
        # handle ZeroDivisionError
        print('Error: ' + str(zde))

dividend = 5
divisor = 0
divide(dividend, divisor)
# Out:
# Error: division by zero

# %% [markdown]
# #### Q2. Implement a Python program to generate all sentences where subject is in ["Americans", "Indians"] and verb is in ["Play", "watch"] and the object is in ["Baseball","cricket"].
# ##### Hint: Subject,Verb and Object should be declared in the program as shown below.
# subjects=["Americans ","Indians"]
#
# verbs=["play","watch"]
#
# objects=["Baseball","Cricket"]
#
# ##### Output should come as below:
# ##### -------------------------------------------------------
# Americans play Baseball.
#
# Americans play Cricket.
#
# Americans watch Baseball.
#
# Americans watch Cricket.
#
# Indians play Baseball.
#
# Indians play Cricket.
#
# Indians watch Baseball.
#
# Indians watch Cricket.

# %%
# Program to generate all sentences

subjects=["Americans","Indians"]
verbs=["play","watch"]
objects=["Baseball","Cricket"]

s_size = len(subjects)
v_size = len(verbs)
o_size = len(objects)

for sub in subjects:
    for verb in verbs:
        for obj in objects:
            print(f'{sub} {verb} {obj}.')
# Out:
# Americans play Baseball.
# Americans play Cricket.
# Americans watch Baseball.
# Americans watch Cricket.
# Indians play Baseball.
# Indians play Cricket.
# Indians watch Baseball.
# Indians watch Cricket.
